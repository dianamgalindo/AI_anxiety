# %% [markdown]
# ## How are people feeling about AI and its impact in the workplace?
# ### Accessing the content of the links collected in the web crawling and cleaning the data
# <hr>
# After crawling through relevant websites, I have built a CSV containing the different articles/ PDFs I would like to
# analyse. In this stage, I will tokenize the content of those articles and clean non-relevant words. The cleaning process will allow for the collection of meaningful words that will contribute to the sentiment analysis stage.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from string import punctuation
import re 
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Diana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Diana\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
dataFrame = pd.read_csv("Crawl_final_links.csv")
dataFrame.drop('Unnamed: 0', inplace=True, axis =1)
dataFrame
# Out:
#                                                 links
# 0   https://futureoflife.org/cause-area/artificial...
# 1   https://futureoflife.org/open-letter/ai-princi...
# 2   https://openai.com/blog/planning-for-agi-and-b...
# 3   https://futureoflife.org/ai/faqs-about-flis-op...
# 4                    https://arxiv.org/abs/2209.10604
# 5                    https://arxiv.org/abs/2206.13353
# 6                    https://arxiv.org/abs/2303.10130
# 7                    https://arxiv.org/abs/2206.05862
# 8                    https://arxiv.org/abs/2209.00626
# 9                    https://arxiv.org/abs/2112.04359
# 10  https://abcnews.go.com/Technology/openai-ceo-s...
# 11  https://time.com/6246119/demis-hassabis-deepmi...
# 12                   https://arxiv.org/abs/2303.12712
# 13  https://futureoflife.org/cause-area/artificial...
# 14  https://www.pwc.com/gx/en/issues/workforce/hop...
# 15  https://www.technologyreview.com/2023/02/08/10...
# 16  https://www.nytimes.com/2023/02/03/technology/...
# 17  https://journals.sagepub.com/doi/full/10.1177/...
# 18  https://news.byu.edu/intellect/robots-are-taki...
# 19      https://www.bbc.com/worklife/work-in-progress

# %%
##Accessing the HTML content of the link
# individual_url = dataFrame['links'][11]
# individual_url
for i in dataFrame['links']:
    print(i)
# Out:
# https://futureoflife.org/cause-area/artificial-intelligence/
# https://futureoflife.org/open-letter/ai-principles/
# https://openai.com/blog/planning-for-agi-and-beyond
# https://futureoflife.org/ai/faqs-about-flis-open-letter-calling-for-a-pause-on-giant-ai-experiments/
# https://arxiv.org/abs/2209.10604
# https://arxiv.org/abs/2206.13353
# https://arxiv.org/abs/2303.10130
# https://arxiv.org/abs/2206.05862
# https://arxiv.org/abs/2209.00626
# https://arxiv.org/abs/2112.04359
# https://abcnews.go.com/Technology/openai-ceo-sam-altman-ai-reshape-society-acknowledges/story?id=97897122
# https://time.com/6246119/demis-hassabis-deepmind-interview/
# https://arxiv.org/abs/2303.12712
# https://futureoflife.org/cause-area/artificial-intelligence/
# https://www.pwc.com/gx/en/issues/workforce/hopes-and-fears-2022.html
# https://www.technologyreview.com/2023/02/08/1068068/chatgpt-is-everywhere-heres-where-it-came-from/
# https://www.nytimes.com/2023/02/03/technology/chatgpt-openai-artificial-intelligence.html
# https://journals.sagepub.com/doi/full/10.1177/23780231221131377
# https://news.byu.edu/intellect/robots-are-taking-over-jobs-but-not-at-the-rate-you-might-think-says-byu-research
# https://www.bbc.com/worklife/work-in-progress

# %%
#get the individual links and convert them in soup objects

def tokenized(url):
    page = requests.get(individual_url)
    soup = BeautifulSoup(page.text, 'html.parser')
    readable_text = soup.get_text()
    
    #Tokenize the text
    tokenized_text = word_tokenize(readable_text.lower())
    return tokenized_text

# %%
#Removing stopwords and punctuation
stop_words = set(stopwords.words('english'))
punctuation = list(punctuation)

def clean(tokenized_text):
    ##extra punctuation that I have found within the texts
    extra_punctuation= '...', '©', '’', '“', '–', '”'
    punctuation.extend(extra_punctuation)

    #print(punctuation)

    #checked if the tokenized words are within the stopwords and punctuation list. If they are, remove.
    filtered_text = []

    for word in tokenized_text:
        pattern = r'[0-9]' #removing string-numbers

        if word not in stop_words and word not in punctuation:
            nword = re.sub(pattern, '', word)
            filtered_text.append(nword)
    return filtered_text

#print(clean(tokenized(i)))

# %%
#Convert punctuation that is within strings to a comma, so that I can further divide the words

def second_clean(filtered_text):
    cleaned_text = []

    for word in filtered_text:
        for char in word:
            if char in punctuation:
                word = word.replace(char, ",")
        cleaned_text.append(word)
    return cleaned_text    

#print(second_clean(clean(tokenized(i))))

# %%
#Remove empty strings, and words that are not long enough to be relevant

def final_clean(cleaned_text): 
    cleaned_text_v2 = []

    for word in cleaned_text:
        if ',' in word:
            cleaned_text_v2.extend(word.split(','))
        else:
            cleaned_text_v2.append(word)
            
    #removing empty strings
    cleaned_text_v2 = list(filter(None, cleaned_text_v2))
    
    ##Removing words that are of lenght less than 1 and more than 12 characters
    final_text = list(filter(lambda word: len(word) > 1 and len(word)<12, cleaned_text_v2))
    return final_text

# print(final_clean(second_clean(clean(tokenized(i)))))

# %% [markdown]
# ## Looping through all the links on my dataFrame and cleaning the text they contain
# <hr>
# After creating the different functions that clean the content of the articles, I have used them to loop through all the links of my initial dataFrame. This process extracts meaningful words from the text content of the articles' HTML <br>
# <strong>What is the best format to save this file ?</strong>

# %%
for individual_url in dataFrame['links']:
#     dataFrame['Tokens'] = pd.array(final_clean(second_clean(clean(tokenized(individual_url)))))
     print(individual_url, final_clean(second_clean(clean(tokenized(individual_url)))))
# Out:
# https://futureoflife.org/cause-area/artificial-intelligence/ ['future', 'life', 'institute', 'skip', 'content', 'mission', 'cause', 'area', 'change', 'workour', 'work', 'risks', 'ai', 'nuclear', 'life', 'nist', 'ai', 'risk', 'european', 'ai', 'lethal', 'life', 'institute', 'podcasts', 'resources', 'usabout', 'us', 'us', 'take', 'action', 'search', 'take', 'action', 'home', 'cause', 'self', 'driving', 'cars', 'ai', 'changing', 'lives', 'impact', 'magnifies', 'risks', 'self', 'driving', 'cars', 'racing', 'forward', 'today', 'narrow', 'ai', 'systems', 'perform', 'isolated', 'tasks', 'already', 'pose', 'major', 'risks', 'erosion', 'processes', 'financial', 'flash', 'crashes', 'arms', 'race', 'weapons', 'looking', 'ahead', 'many', 'pursuing', 'agi', 'general', 'ai', 'perform', 'well', 'better', 'humans', 'wide', 'range', 'cognitive', 'tasks', 'ai', 'systems', 'design', 'smarter', 'systems', 'may', 'hit', 'explosion', 'quickly', 'leaving', 'humanity', 'behind', 'could', 'eradicate', 'poverty', 'war', 'could', 'also', 'eradicate', 'us', 'risk', 'comes', 'ai', 'potential', 'words', 'feels', 'humans', 'could', 'instance', 'lose', 'control', 'high', 'system', 'something', 'impact', 'even', 'ai', 'something', 'could', 'still', 'develop', 'method', 'achieve', 'goal', 'ai', 'need', 'pursue', 'goals', 'heat', 'seeking', 'missiles', 'equally', 'danger', 'robots', 'per', 'se', 'requires', 'nothing', 'internet', 'us', 'harm', 'still', 'loom', 'large', 'public', 'discourse', 'however', 'thanks', 'experts', 'speaking', 'issues', 'machine', 'learning', 'reaching', 'certain', 'far', 'earlier', 'expected', 'informed', 'interest', 'ai', 'safety', 'major', 'concern', 'blossomed', 'recent', 'years', 'super', 'yet', 'might', 'right', 'around', 'corner', 'might', 'never', 'happen', 'either', 'way', 'long', 'win', 'race', 'growing', 'power', 'wisdom', 'design', 'manage', 'ai', 'best', 'way', 'win', 'race', 'impede', 'former', 'latter', 'ai', 'safety', 'research', 'risk', 'since', 'may', 'take', 'decades', 'complete', 'research', 'prudent', 'start', 'ai', 'safety', 'research', 'prepares', 'us', 'better', 'future', 'pre', 'emptively', 'making', 'ai', 'society', 'reducing', 'risks', 'meanwhile', 'policy', 'possibly', 'form', 'reform', 'pace', 'ai', 'risks', 'must', 'therefore', 'pre', 'emptive', 'inclusive', 'dangers', 'present', 'risks', 'siri', 'self', 'driving', 'cars', 'ai', 'rapidly', 'science', 'fiction', 'often', 'portrays', 'ai', 'robots', 'human', 'like', 'ai', 'encompass', 'anything', 'google', 'search', 'ibm', 'watson', 'weapons', 'read', 'article', 'ai', 'policyhow', 'countries', 'around', 'world', 'benefits', 'risks', 'ai', 'ai', 'holds', 'great', 'december', 'value', 'alignment', 'research', 'landscape', 'variety', 'ai', 'safety', 'research', 'agendas', 'along', 'papers', 'ai', 'machine', 'learning', 'ethics', 'november', 'videosour', 'content', 'videohow', 'get', 'empowered', 'aifuture', 'life', 'science', 'fiction', 'future', 'life', 'facts', 'aifuture', 'life', 'postsour', 'ai', 'policy', 'using', 'natural', 'language', 'interest', 'ai', 'grows', 'across', 'globe', 'focused', 'attention', 'soft', 'december', 'see', 'page', 'languages', 'chinese', 'french', 'german', 'japanese', 'russian', 'future', 'ai', 'think', 'max', 'august', 'posta', 'ai', 'asilomar', 'took', 'place', 'backdrop', 'growing', 'interest', 'wider', 'society', 'potential', 'january', 'postwhen', 'ai', 'goes', 'badslate', 'currently', 'running', 'feature', 'called', 'future', 'tense', 'claims', 'citizens', 'guide', 'future', 'two', 'april', 'resources', 'ai', 'safety', 'list', 'get', 'speed', 'main', 'ideas', 'field', 'resources', 'selected', 'relevance', 'and', 'or', 'brevity', 'february', 'reddit', 'ama', 'aiour', 'advisory', 'board', 'member', 'stephen', 'hawking', 'long', 'awaited', 'reddit', 'ama', 'answers', 'came', 'today', 'october', 'postai', 'asked', 'questions', 'future', 'click', 'see', 'page', 'languages', 'chinese', 'german', 'japanese', 'korean', 'october', 'p ...
# https://futureoflife.org/open-letter/ai-principles/ ['ai', 'future', 'life', 'institute', 'skip', 'content', 'mission', 'cause', 'area', 'change', 'workour', 'work', 'risks', 'ai', 'nuclear', 'life', 'nist', 'ai', 'risk', 'european', 'ai', 'lethal', 'life', 'institute', 'podcasts', 'resources', 'usabout', 'us', 'us', 'take', 'action', 'search', 'take', 'action', 'home', 'ai', 'open', 'lettersai', 'asilomar', 'ai', 'fli', 'developed', 'ai', 'one', 'earliest', 'sets', 'ai', 'developed', 'asilomar', 'videos', 'process', 'described', 'click', 'see', 'page', 'languages', 'chinese', 'german', 'japanese', 'korean', 'russian', 'already', 'provided', 'tools', 'used', 'every', 'day', 'people', 'around', 'world', 'continued', 'guided', 'following', 'offer', 'amazing', 'help', 'empower', 'people', 'decades', 'centuries', 'ahead', 'research', 'issues', 'research', 'goal', 'goal', 'ai', 'research', 'create', 'research', 'funding', 'ai', 'funding', 'research', 'ensuring', 'use', 'including', 'thorny', 'questions', 'computer', 'science', 'economics', 'law', 'ethics', 'social', 'studies', 'make', 'future', 'ai', 'systems', 'highly', 'robust', 'want', 'without', 'getting', 'hacked', 'grow', 'people', 'resources', 'purpose', 'update', 'legal', 'systems', 'fair', 'efficient', 'keep', 'pace', 'ai', 'manage', 'risks', 'ai', 'set', 'values', 'ai', 'aligned', 'legal', 'ethical', 'status', 'science', 'policy', 'link', 'healthy', 'exchange', 'ai', 'policy', 'makers', 'research', 'culture', 'culture', 'trust', 'fostered', 'among', 'ai', 'race', 'avoidance', 'teams', 'ai', 'systems', 'actively', 'cooperate', 'avoid', 'corner', 'cutting', 'safety', 'standards', 'ethics', 'values', 'safety', 'ai', 'systems', 'safe', 'secure', 'lifetime', 'feasible', 'failure', 'ai', 'system', 'causes', 'harm', 'possible', 'ascertain', 'judicial', 'system', 'judicial', 'decision', 'making', 'provide', 'auditable', 'competent', 'human', 'authority', 'designers', 'builders', 'advanced', 'ai', 'systems', 'moral', 'use', 'misuse', 'actions', 'shape', 'value', 'alignment', 'highly', 'ai', 'systems', 'designed', 'goals', 'behaviors', 'assured', 'align', 'human', 'values', 'operation', 'human', 'values', 'ai', 'systems', 'designed', 'operated', 'ideals', 'human', 'dignity', 'rights', 'freedoms', 'cultural', 'diversity', 'personal', 'privacy', 'people', 'right', 'access', 'manage', 'control', 'data', 'generate', 'given', 'ai', 'systems', 'power', 'analyze', 'utilize', 'data', 'liberty', 'privacy', 'ai', 'personal', 'data', 'must', 'curtail', 'people', 'real', 'perceived', 'liberty', 'shared', 'benefit', 'ai', 'benefit', 'empower', 'many', 'people', 'possible', 'shared', 'economic', 'created', 'ai', 'shared', 'broadly', 'benefit', 'humanity', 'human', 'control', 'humans', 'choose', 'whether', 'delegate', 'decisions', 'ai', 'systems', 'human', 'chosen', 'non', 'power', 'conferred', 'control', 'highly', 'advanced', 'ai', 'systems', 'respect', 'improve', 'rather', 'subvert', 'social', 'civic', 'processes', 'health', 'society', 'depends', 'ai', 'arms', 'race', 'arms', 'race', 'lethal', 'weapons', 'avoided', 'longer', 'term', 'issues', 'caution', 'consensus', 'avoid', 'strong', 'regarding', 'upper', 'limits', 'future', 'ai', 'advanced', 'ai', 'could', 'represent', 'profound', 'change', 'history', 'life', 'earth', 'planned', 'managed', 'care', 'resources', 'risks', 'risks', 'posed', 'ai', 'systems', 'risks', 'must', 'subject', 'planning', 'efforts', 'expected', 'impact', 'recursive', 'self', 'ai', 'systems', 'designed', 'self', 'improve', 'self', 'replicate', 'manner', 'could', 'lead', 'rapidly', 'quality', 'quantity', 'must', 'subject', 'strict', 'safety', 'control', 'measures', 'common', 'good', 'developed', 'service', 'widely', 'shared', 'ethical', 'ideals', 'benefit', 'humanity', 'rather', 'one', 'state', 'add', 'signature', 'express', 'support', 'please', 'add', 'name', 'thank', 'support', 'please', 'help', 'build', 'momentum', 'emailing', 'link', 'org', 'open', 'letter', 'ai', 'thin ...
# https://openai.com/blog/planning-for-agi-and-beyond ['planning', 'agi', 'beyond', 'submit', 'skip', 'main', 'dallâ·e', 'customer', 'mobile', 'closesite', 'submit', 'planning', 'agi', 'beyondour', 'mission', 'ensure', 'general', 'systems', 'generally', 'smarter', 'ofâ', 'humanity', 'justin', 'jay', 'wang', 'ã\x97', 'mission', 'ensure', 'general', 'systems', 'generally', 'smarter', 'ofâ', 'humanity', 'if', 'agi', 'created', 'could', 'help', 'us', 'elevate', 'humanity', 'abundance', 'global', 'economy', 'aiding', 'discovery', 'new', 'knowledge', 'changes', 'limits', 'ofâ', 'agi', 'potential', 'give', 'everyone', 'new', 'imagine', 'world', 'us', 'access', 'help', 'almost', 'cognitive', 'task', 'providing', 'great', 'force', 'human', 'ingenuity', 'andâ', 'on', 'hand', 'agi', 'would', 'also', 'come', 'serious', 'risk', 'misuse', 'drastic', 'accidents', 'societal', 'upside', 'agi', 'great', 'believe', 'possible', 'desirable', 'society', 'stop', 'forever', 'instead', 'society', 'agi', 'figure', 'get', 'right', 'gifts', 'although', 'predict', 'exactly', 'happen', 'course', 'current', 'progress', 'could', 'hit', 'wall', 'care', 'aboutâ', 'want', 'agi', 'empower', 'humanity', 'maximally', 'flourish', 'universe', 'donâ\x80\x99t', 'expect', 'future', 'utopia', 'want', 'maximize', 'good', 'minimize', 'bad', 'agi', 'amplifier', 'ofâ', 'humanity', 'we', 'want', 'benefits', 'access', 'agi', 'widely', 'fairlyâ', 'shared', 'we', 'want', 'navigate', 'massive', 'risks', 'risks', 'seems', 'right', 'theory', 'often', 'plays', 'strangely', 'expected', 'practice', 'believe', 'learn', 'adapt', 'deploying', 'less', 'powerful', 'versions', 'order', 'minimize', 'â\x80\x9cone', 'shot', 'get', 'rightâ\x80\x9dâ', 'scenarios', 'the', 'short', 'termthere', 'several', 'things', 'think', 'important', 'prepare', 'forâ', 'agi', 'first', 'create', 'powerful', 'systems', 'want', 'deploy', 'gain', 'operating', 'real', 'world', 'believe', 'best', 'way', 'carefully', 'steward', 'agi', 'gradual', 'world', 'agi', 'better', 'sudden', 'one', 'expect', 'powerful', 'ai', 'make', 'rate', 'progress', 'world', 'much', 'faster', 'think', 'itâ\x80\x99s', 'better', 'adjust', 'thisâ', 'gradual', 'gives', 'people', 'time', 'whatâ\x80\x99s', 'happening', 'benefits', 'downsides', 'systems', 'adapt', 'economy', 'put', 'place', 'also', 'allows', 'society', 'ai', 'co', 'evolve', 'people', 'figure', 'want', 'stakes', 'low', 'we', 'currently', 'believe', 'best', 'way', 'navigate', 'ai', 'tight', 'feedback', 'loop', 'rapid', 'learning', 'careful', 'iteration', 'society', 'face', 'major', 'questions', 'ai', 'systems', 'allowed', 'combat', 'bias', 'deal', 'job', 'optimal', 'decisions', 'depend', 'path', 'takes', 'like', 'new', 'field', 'expert', 'wrong', 'far', 'makes', 'planning', 'vacuum', 'difficult', 'planning', 'generally', 'speaking', 'think', 'usage', 'ai', 'world', 'lead', 'good', 'want', 'promote', 'putting', 'models', 'api', 'open', 'sourcing', 'etc', 'believe', 'access', 'also', 'lead', 'better', 'research', 'power', 'benefits', 'broader', 'set', 'people', 'newâ', 'ideas', 'as', 'systems', 'get', 'closer', 'agi', 'becoming', 'cautious', 'creation', 'models', 'decisions', 'require', 'much', 'caution', 'society', 'usually', 'applies', 'new', 'caution', 'many', 'users', 'would', 'like', 'people', 'ai', 'field', 'think', 'risks', 'agi', 'successor', 'systems', 'would', 'delighted', 'turn', 'right', 'going', 'operate', 'risks', 'areâ', 'at', 'point', 'balance', 'upsides', 'downsides', 'malicious', 'actors', 'creating', 'social', 'economic', 'unsafe', 'race', 'could', 'shift', 'case', 'would', 'change', 'plans', 'around', 'as', 'systems', 'get', 'closer', 'agi', 'becoming', 'cautious', 'creation', 'models', 'second', 'working', 'towards', 'creating', 'aligned', 'steerable', 'models', 'shift', 'models', 'like', 'first', 'version', 'gpt', 'toâ', 'andâ', 'chatgptâ', 'early', 'example', 'ofâ', 'this', 'in', 'think', 'itâ\x80\x99s', 'important', 'society', 'agree', 'extremely', 'wide', 'bound ...
# https://futureoflife.org/ai/faqs-about-flis-open-letter-calling-for-a-pause-on-giant-ai-experiments/ ['faqs', 'fli', 'open', 'letter', 'calling', 'pause', 'giant', 'ai', 'future', 'life', 'institute', 'skip', 'content', 'mission', 'cause', 'area', 'change', 'workour', 'work', 'risks', 'ai', 'nuclear', 'life', 'nist', 'ai', 'risk', 'european', 'ai', 'lethal', 'life', 'institute', 'podcasts', 'resources', 'usabout', 'us', 'us', 'take', 'action', 'search', 'take', 'action', 'home', 'faqs', 'fli', 'open', 'letter', 'calling', 'pause', 'giant', 'ai', 'post', 'minute', 'read', 'faqs', 'fli', 'open', 'letter', 'calling', 'pause', 'giant', 'ai', 'please', 'note', 'faq', 'prepared', 'fli', 'reflect', 'views', 'letter', 'live', 'document', 'continue', 'updated', 'response', 'questions', 'media', 'elsewhere', 'faqs', 'reference', 'pause', 'giant', 'ai', 'open', 'letter', 'letter', 'call', 'calling', 'pause', 'training', 'models', 'larger', 'gpt', 'months', 'imply', 'pause', 'ban', 'ai', 'research', 'use', 'systems', 'already', 'placed', 'market', 'call', 'specific', 'addresses', 'small', 'pool', 'actors', 'possess', 'reaction', 'letter', 'reaction', 'intense', 'feel', 'given', 'voice', 'huge', 'concern', 'risks', 'high', 'powered', 'ai', 'systems', 'public', 'level', 'top', 'ai', 'topics', 'business', 'leaders', 'writing', 'signed', 'letter', 'even', 'signature', 'efforts', 'lagging', 'including', 'ceos', 'letter', 'also', 'generated', 'intense', 'media', 'coverage', 'added', 'momentum', 'action', 'goes', 'far', 'beyond', 'fli', 'efforts', 'week', 'letter', 'center', 'digital', 'policy', 'asked', 'ftc', 'stop', 'new', 'gpt', 'releases', 'unesco', 'called', 'world', 'enact', 'global', 'ethical', 'ai', 'framework', 'wrote', 'letter', 'fli', 'staff', 'ai', 'experts', 'yoshua', 'bengio', 'stuart', 'russell', 'heads', 'several', 'ai', 'focused', 'ngos', 'composed', 'letter', 'found', 'letter', 'asked', 'sign', 'letter', 'fuel', 'ai', 'hype', 'current', 'ai', 'systems', 'becoming', 'quite', 'general', 'already', 'human', 'wide', 'variety', 'tasks', 'extremely', 'important', 'many', 'world', 'leading', 'ai', 'also', 'think', 'powerful', 'systems', 'often', 'called', 'general', 'agi', 'humanity', 'best', 'almost', 'task', 'stated', 'goal', 'many', 'ai', 'labs', 'natural', 'law', 'barrier', 'technical', 'progress', 'prohibits', 'therefore', 'operate', 'agi', 'possible', 'sooner', 'many', 'expected', 'perhaps', 'many', 'others', 'wrong', 'society', 'profound', 'still', 'think', 'agi', 'hype', 'ok', 'issue', 'even', 'work', 'ai', 'every', 'day', 'name', 'fact', 'ai', 'systems', 'growing', 'ever', 'powerful', 'know', 'upper', 'bound', 'malicious', 'actors', 'use', 'systems', 'bad', 'things', 'regular', 'consumers', 'might', 'misled', 'worse', 'output', 'showed', 'model', 'meant', 'generate', 'drugs', 'could', 'used', 'generate', 'novel', 'weapons', 'instead', 'openai', 'system', 'card', 'gpt', 'could', 'prompted', 'tricking', 'worker', 'complete', 'captcha', 'recently', 'tragic', 'news', 'report', 'covered', 'committed', 'suicide', 'gpt', 'clone', 'public', 'comments', 'leaders', 'labs', 'like', 'openai', 'anthropic', 'deepmind', 'risks', 'called', 'also', 'believe', 'would', 'like', 'pause', 'might', 'feel', 'pressure', 'continue', 'training', 'deploying', 'larger', 'models', 'nothing', 'else', 'public', 'pause', 'labs', 'alleviate', 'pressure', 'encourage', 'mean', 'concerned', 'present', 'harms', 'use', 'ai', 'systems', 'capacity', 'create', 'harms', 'bias', 'economic', 'power', 'adverse', 'impact', 'labor', 'reaffirm', 'harms', 'also', 'deeply', 'merit', 'work', 'solve', 'grateful', 'work', 'many', 'scholars', 'business', 'leaders', 'diplomats', 'working', 'surface', 'national', 'level', 'fli', 'supported', 'address', 'harms', 'mentioned', 'including', 'nist', 'ai', 'rmf', 'ftc', 'action', 'ai', 'claims', 'eu', 'ai', 'act', 'liability', 'directive', 'arms', 'control', 'weapons', 'un', 'fora', 'possible', 'enjoy', 'positive', 'futures', 'ai', 'pr ...
', 'replicate', 'toggle', 'replicate', 'replicate', 'spaces', 'toggle', 'hugging', 'face', 'spaces', 'spaces', 'related', 'papers', 'search', 'tools', 'link', 'influence', 'flower', 'influence', 'flower', 'influence', 'flowers', 'connected', 'papers', 'toggle', 'connected', 'papers', 'connected', 'papers', 'core', 'toggle', 'core', 'core', 'author', 'venue', 'topic', 'arxivlabs', 'arxivlabs', 'projects', 'community', 'arxivlabs', 'framework', 'allows', 'develop', 'share', 'new', 'arxiv', 'features', 'directly', 'website', 'work', 'arxivlabs', 'embraced', 'accepted', 'values', 'openness', 'community', 'user', 'data', 'privacy', 'arxiv', 'committed', 'values', 'works', 'partners', 'adhere', 'idea', 'project', 'add', 'value', 'arxiv', 'community', 'learn', 'arxivlabs', 'authors', 'paper', 'endorsers', 'disable', 'mathjax', 'mathjax', 'help', 'contact', 'contact', 'arxiv', 'contact', 'subscribe', 'arx ...
# https://arxiv.org/abs/2206.13353 ['power', 'seeking', 'ai', 'risk', 'skip', 'main', 'content', 'support', 'fromthe', 'simons', 'member', 'cs', 'arxiv', 'help', 'advanced', 'search', 'fields', 'title', 'author', 'abstract', 'comments', 'journal', 'reference', 'acm', 'msc', 'report', 'number', 'arxiv', 'doi', 'orcid', 'arxiv', 'author', 'id', 'help', 'pages', 'full', 'text', 'search', 'open', 'search', 'go', 'open', 'menu', 'quick', 'links', 'login', 'help', 'pages', 'computer', 'science', 'computers', 'society', 'arxiv', 'cs', 'submitted', 'jun', 'title', 'power', 'seeking', 'ai', 'risk', 'authors', 'joseph', 'carlsmith', 'download', 'pdf', 'paper', 'titled', 'power', 'seeking', 'ai', 'risk', 'joseph', 'carlsmith', 'download', 'pdf', 'abstract', 'report', 'examines', 'see', 'core', 'argument', 'concern', 'risk', 'proceed', 'two', 'stages', 'first', 'lay', 'backdrop', 'picture', 'informs', 'concern', 'picture', 'agency', 'extremely', 'powerful', 'force', 'creating', 'agents', 'much', 'us', 'playing', 'fire', 'given', 'agents', 'would', 'plausibly', 'seek', 'power', 'humans', 'second', 'formulate', 'evaluate', 'specific', 'six', 'premise', 'argument', 'creating', 'agents', 'kind', 'lead', 'argument', 'become', 'possible', 'feasible', 'build', 'powerful', 'agentic', 'ai', 'systems', 'strong', 'much', 'harder', 'build', 'aligned', 'powerful', 'agentic', 'ai', 'systems', 'build', 'powerful', 'agentic', 'ai', 'systems', 'still', 'deploy', 'systems', 'seek', 'power', 'humans', 'high', 'impact', 'ways', 'problem', 'scale', 'full', 'humanity', 'assign', 'rough', 'credences', 'premises', 'argument', 'end', 'overall', 'estimate', 'kind', 'occur', 'may', 'update', 'since', 'making', 'report', 'public', 'april', 'estimate', 'gone', 'comments', 'pages', 'figure', 'subjects', 'computers', 'society', 'cs', 'cy', 'cs', 'ai', 'machine', 'learning', 'cs', 'lg', 'cite', 'arxiv', 'cs', 'cy', 'arxiv', 'cs', 'cy', 'version', 'https', 'doi', 'org', 'arxiv', 'focus', 'learn', 'arxiv', 'issued', 'doi', 'via', 'datacite', 'history', 'jo
large', 'language', 'models', 'tyna', 'eloundou', 'authors', 'download', 'pdf', 'abstract', 'potential', 'large', 'language', 'models', 'llms', 'pre', 'trained', 'gpts', 'labor', 'market', 'focusing', 'increased', 'arising', 'llm', 'powered', 'software', 'compared', 'llms', 'using', 'new', 'rubric', 'assess', 'based', 'alignment', 'llm', 'human', 'expertise', 'gpt', 'findings', 'reveal', 'around', 'workforce', 'could', 'least', 'work', 'tasks', 'affected', 'llms', 'workers', 'may', 'see', 'least', 'tasks', 'impacted', 'make', 'adoption', 'timeline', 'llms', 'projected', 'effects', 'span', 'wage', 'levels', 'higher', 'income', 'jobs', 'facing', 'greater', 'exposure', 'llm', 'llm', 'powered', 'software', 'impacts', 'higher', 'recent', 'growth', 'analysis', 'suggests', 'access', 'llm', 'worker', 'tasks', 'us', 'could', 'completed', 'faster', 'level', 'quality', 'software', 'tooling', 'built', 'top', 'llms', 'share', 'increases', 'tasks', 'finding', 'implies', 'llm', 'powered', 'software', 'effect', 'scaling', 'economic', 'impacts', 'models', 'conclude', 'llms', 'gpts', 'exhibit', 'traits', 'general', 'purpose', 'could', 'economic', 'social', 'policy', 'subjects', 'general', 'economics', 'econ', 'gn', 'cs', 'ai', 'computers', 'society', 'cs', 'cy', 'cite', 'arxiv', 'econ', 'gn', 'arxiv', 'econ', 'gn', 'version', 'https', 'doi', 'org', 'arxiv', 'focus', 'learn', 'arxiv', 'issued', 'doi', 'via', 'datacite', 'history', 'daniel', 'rock', 'view', 'email', 'fri', 'mar', 'utc', 'kb', 'mon', 'mar', 'utc', 'kb', 'wed', 'mar', 'utc', 'kb', 'thu', 'mar', 'utc', 'kb', 'full', 'text', 'links', 'download', 'download', 'pdf', 'paper', 'titled', 'gpts', 'gpts', 'early', 'look', 'labor', 'market', 'impact', 'potential', 'large', 'language', 'models', 'tyna', 'eloundou', 'authors', 'pdf', 'formats', 'current', 'browse', 'context', 'econ', 'gn', 'prev', 'next', 'new', 'recent', 'change', 'browse', 'cs', 'cs', 'ai', 'cs', 'cy', 'econ', 'fin', 'fin', 'ec', 'citations', 'nasa', 'adsgoogle', 'scholar', 'semantic', 'scholar', 'blog', 'link', 'export', 'bibtex', 'citation', 'loading', 'bibtex', 'formatted', 'citation', 'loading', 'data', 'provided', 'bookmark', 'tools', 'citation', 'tools', 'explorer', 'toggle', 'explorer', 'explorer', 'litmaps', 'toggle', 'litmaps', 'litmaps', 'scite', 'ai', 'toggle', 'scite', 'smart', 'citations', 'smart', 'citations', 'code', 'data', 'media', 'code', 'data', 'media', 'article', 'dagshub', 'toggle', 'dagshub', 'dagshub', 'links', 'code', 'toggle', 'papers', 'code', 'papers', 'code', 'toggle', 'demos', 'demos', 'replicate', 'toggle', 'replicate', 'replicate', 'spaces', 'toggle', 'hugging', 'face', 'spaces', 'spaces', 'related', 'papers', 'search', 'tools', 'link', 'influence', 'flower', 'influence', 'flower', 'influence', 'flowers', 'connected', 'papers', 'toggle', 'connected', 'papers', 'connected', 'papers', 'core', 'toggle', 'core', 'core', 'author', 'venue', 'topic', 'arxivlabs', 'arxivlabs', 'projects', 'community', 'arxivlabs', 'framework', 'allows', 'develop',  ...
sgoogle', 'scholar', 'semantic', 'scholar', 'export', 'bibtex', 'citation', 'loading', 'bibtex', 'formatted', 'citation', 'loading', 'data', 'provided', 'bookmark', 'tools', 'citation', 'tools', 'explorer', 'toggle', 'explorer', 'explorer', 'litmaps', 'toggle', 'litmaps', 'litmaps', 'scite', 'ai', 'toggle', 'scite', 'smart', 'citations', 'smart', 'citations', 'code', 'data', 'media', 'code', 'data', 'media', 'article', 'dagshub', 'toggle', 'dagshub', 'dagshub', 'links', 'code', 'toggle', 'papers', 'code', 'papers', 'code', 'toggle', 'demos', 'demos', 'replicate', 'toggle', 'replicate', 'replicate', 'spaces', 'toggle', 'hugging', 'face', 'spaces', 'spaces', 'related', 'papers', 'search', 'tools', 'link', 'influence', 'flower', 'influence', 'flower', 'influence', 'flowers', 'connected', 'papers', 'toggle', 'connected', 'papers', 'connected', 'papers', 'core', 'toggle', 'core', 'core', 'author', 'venue', 'topic', 'arxivlabs', 'arxivlabs', 'projects', 'community', 'arxivlabs', 'framework', 'allows', 'develop', 'share', 'new', 'arxiv', 'features', 'directly', 'website', 'work', 'arxivlabs', 'embraced', 'accepted', 'values', 'openness', 'community', 'user', 'data', 'privacy', 'arxiv', 'committed', 'values', 'works', 'partners', 'adhere', 'idea', 'project', 'add', 'value', 'arxiv', 'com ...
# https://arxiv.org/abs/2209.00626 ['alignment', 'problem', 'deep', 'learning', 'skip', 'main', 'content', 'support', 'fromthe', 'simons', 'member', 'cs', 'arxiv', 'help', 'advanced', 'search', 'fields', 'title', 'author', 'abstract', 'comments', 'journal', 'reference', 'acm', 'msc', 'report', 'number', 'arxiv', 'doi', 'orcid', 'arxiv', 'author', 'id', 'help', 'pages', 'full', 'text', 'search', 'open', 'search', 'go', 'open', 'menu', 'quick', 'links', 'login', 'help', 'pages', 'computer', 'science', 'arxiv', 'cs', 'submitted', 'aug', 'last', 'revised', 'feb', 'version', 'title', 'alignment', 'problem', 'deep', 'learning', 'authors', 'richard', 'ngo', 'lawrence', 'chan', 'sören', 'download', 'pdf', 'paper', 'titled', 'alignment', 'problem', 'deep', 'learning', 'richard', 'ngo', 'authors', 'download', 'pdf', 'abstract', 'within', 'coming', 'decades', 'general', 'agi', 'may', 'surpass', 'human', 'wide', 'range', 'important', 'tasks', 'outline', 'case', 'expecting', 'without', 'effort', 'prevent', 'agis', 'could', 'learn', 'pursue', 'goals', 'human', 'argue', 'agis', 'trained', 'ways', 'similar', 'today', 'capable', 'models', 'could', 'learn', 'act', 'receive', 'higher', 'reward', 'learn', 'goals', 'beyond', 'training', 'pursue', 'goals', 'using', 'power', 'seeking', 'outline', 'agis', 'might', 'undermine', 'human', 'control', 'world', 'briefly', 'review', 'research', 'aimed', 'outcome', 'subjects', 'cs', 'ai', 'machine', 'learning', 'cs', 'lg', 'cite', 'arxiv', 'cs', 'ai', 'arxiv', 'cs', 'ai', 'version', 'https', 'doi', 'org', 'arxiv', 'focus', 'learn', 'arxiv', 'issued', 'doi', 'via', 'datacite', 'history', 'richard', 'ngo', 
 'sasha', 'brown', 'hawkins', 'tom', 'stepleton', 'courtney', 'biles', 'abeba', 'birhane', 'julia', 'haas', 'laura', 'rimell', 'lisa', 'anne', 'hendricks', 'william', 'isaac', 'sean', 'legassick', 'geoffrey', 'irving', 'iason', 'gabriel', 'download', 'pdf', 'paper', 'titled', 'ethical', 'social', 'risks', 'harm', 'language', 'models', 'laura', 'weidinger', 'authors', 'download', 'pdf', 'abstract', 'paper', 'aims', 'help', 'structure', 'risk', 'landscape', 'large', 'scale', 'language', 'models', 'lms', 'order', 'foster', 'advances', 'in', 'depth', 'potential', 'risks', 'posed', 'models', 'needed', 'wide', 'range', 'risks', 'analysed', 'detail', 'drawing', 'expertise', 'computer', 'science', 'social', 'sciences', 'outline', 'six', 'specific', 'risk', 'areas', 'exclusion', 'toxicity', 'ii', 'hazards', 'iii', 'harms', 'malicious', 'uses', 'human', 'computer', 'harms', 'vi', 'access', 'harms', 'first', 'area', 'concerns', 'unfair', 'norms', 'toxic', 'language', 'lower', 'social', 'group', 'lms', 'second', 'focuses', 'risks', 'private', 'data', 'leaks', 'lms', 'correctly', 'inferring', 'sensitive', 'third', 'addresses', 'risks', 'arising', 'poor', 'false', 'including', 'sensitive', 'domains', 'knock', 'on', 'risks', 'erosion', 'trust', 'shared', 'fourth', 'considers', 'risks', 'actors', 'try', 'use', 'lms', 'cause', 'harm', 'fifth', 'focuses', 'risks', 'specific', 'llms', 'used', 'underpin', 'agents', 'interact', 'human', 'users', 'including', 'unsafe', 'use', 'deception', 'sixth', 'discusses', 'risk', 'harm', 'job', 'may', 'disparate', 'effect', 'different', 'social', 'groups', 'total', 'review', 'risks', 'in', 'depth', 'discuss', 'points', 'origin', 'different', 'risks', 'point', 'potential', 'lastly', 'discuss', 'role', 'highlight', 'research', 'expanding', 'toolkit', 'assessing', 'outlined', 'risks', 'lms', 'subjects', 'language', 'cs', 'cl', 'cs', 'ai', 'computers', 'society', 'cs', 'cy', 'cite', 'arxiv', 'cs', 'cl', 'arxiv', 'cs', 'cl', 'version', 'https', 'doi', 'org', 'arxiv', 'focus', 'learn', 'arxiv', 'issued', 'doi', 'via', 'datacite', 'history', 'laura', 'weidinger', 'view', 'email', 'wed', 'dec', 'utc', 'kb', 'full', 'text', 'links', 'download', 'download', 'pdf', 'paper', 'titled', 'ethical', 'social', 'risks', 'harm', 'language', 'models', 'laura', 'weidinger', 'authors', 'pdf', 'formats', 'current', 'browse', 'context', 'cs', 'cl', 'prev', 'next', 'new', 'recent', 'change', 'browse', 'cs', 'cs', 'ai', 'cs', 'cy', 'citations', 'nasa', 'adsgoogle', 'scholar', 'semantic', 'scholar', 'blog', 'link', 'dblp', 'cs', 'listing', 'bibtex', 'jonathan', 'uesatopo', 'sen', 'balletom', 'rimell', 'export', 'bibtex', 'citation', 'loading', 'bibtex', 'formatted', 'citation', 'loading', 'data', 'provided', 'bookmark', 'tools', 'citation', 'tools', 'explorer', 'toggle', 'explorer', 'explorer', 'litmaps', 'toggle', 'litmaps', 'litmaps', 'scite', 'ai', 'toggle', 'scite', 'smart', 'citations', 'smart', 'citations', 'code', 'data', 'media', 'code', 'data', 'media', 'article', 'dagshub', 'toggle', 'dagshub', 'dagshub', 'links', 'code', 'toggle', 'papers', 'code', 'papers', 'code', 'toggle', 'demos', 'demos',  ...
# https://abcnews.go.com/Technology/openai-ceo-sam-altman-ai-reshape-society-acknowledges/story?id=97897122 ['openai', 'ceo', 'sam', 'altman', 'says', 'ai', 'reshape', 'society', 'risks', 'little', 'bit', 'scared', 'abc', 'news', 'abc', 'addedwe', 'll', 'notify', 'news', 'aboutturn', 'desktop', 'breaking', 'stories', 'interest', 'onopenai', 'ceo', 'sam', 'altman', 'says', 'ai', 'reshape', 'society', 'risks', 'little', 'bit', 'scared', 'greatest', 'humanity', 'yet', 'developed', 'said', 'byvictor', 'ordonez', 'taylor', 'dunn', 'eric', 'nollmarch', 'pm', 'openai', 'ceo', 'sam', 'altman', 'speaks', 'abc', 'news', 'mar', 'abc', 'newsthe', 'ceo', 'behind', 'company', 'created', 'chatgpt', 'believes', 'reshape', 'society', 'know', 'believes', 'comes', 'real', 'dangers', 'also', 'greatest', 'humanity', 'yet', 'developed', 'improve', 'lives', 've', 'got', 'careful', 'said', 'sam', 'altman', 'ceo', 'openai', 'think', 'people', 'happy', 'little', 'bit', 'scared', 'altman', 'sat', 'exclusive', 'interview', 'abc', 'news', 'chief', 'business', 'economics', 'rebecca', 'jarvis', 'talk', 'rollout', 'gpt', 'latest', 'iteration', 'ai', 'language', 'model', 'more', 'openai', 'releases', 'gpt', 'claims', 'chatbot', 'smarter', 'previous', 'interview', 'altman', 'emphatic', 'openai', 'needs', 'society', 'involved', 'possible', 'rollout', 'chatgpt', 'insisting', 'feedback', 'help', 'deter', 'potential', 'negative', 'could', 'humanity', 'added', 'regular', 'contact', 'officials', 'chatgpt', 'ai', 'language', 'model', 'gpt', 'stands', 'pre', 'trained', 'released', 'months', 'ago', 'already', 'fastest', 'growing', 'consumer', 'history', 'app', 'hit', 'million', 'monthly', 'active', 'users', 'months', 'tiktok', 'took', 'nine', 'months', 'reach', 'many', 'users', 'instagram', 'took', 'nearly', 'three', 'years', 'according', 'ubs', 'study', 'watch', 'exclusive', 'interview', 'sam', 'altman', 'world', 'news', 'tonight', 'david', 'muir', 'et', 'abc', 'though', 'perfect', 'per', 'altman', 'gpt', 'scored', 'th', 'uniform', 'bar', 'exam', 'also', 'scored', 'near', 'perfect', 'score', 'sat', 'math', 'test', 'write', 'computer', 'code', 'languages', 'gpt', 'one', 'step', 'toward', 'openai', 'goal', 'build', 'general', 'ai', 'crosses', 'powerful', 'threshold', 'could', 'described', 'ai', 'systems', 'generally', 'smarter', 'humans', 'though', 'success', 'product', 'altman', 'possible', 'dangerous', 'ai', 'keep', 'night', 'openai', 'ceo', 'sam', 'altman', 'speaks', 'abc', 'news', 'chief', 'business', 'economics', 'rebecca', 'jarvis', 'mar', 'abc', 'news', 'worried', 'models', 'could', 'used', 'large', 'scale', 'altman', 'said', 're', 
way', 'spiral', 'staircase', 'surveying', 'cathedral', 'built', 'behind', 'light', 'glints', 'rungs', 'golden', 'helix', 'rising', 'staircase', 'airy', 'well', 'dna', 'sculpture', 'spanning', 'three', 'floors', 'deepmind', 'recently', 'opened', 'london', 'artistic', 'code', 'embedded', 'nucleus', 'nearly', 'every', 'cell', 'human', 'body', 'although', 'work', 'making', 'machines', 'smart', 'wanted', 'keep', 'humanity', 'center', 'hassabis', 'deepmind', 'ceo', 'co', 'founder', 'tells', 'time', 'building', 'says', 'cathedral', 'knowledge', 'meeting', 'room', 'named', 'famous', 'scientist', 'meet', 'one', 'dedicated', 'james', 'clerk', 'maxwell', 'man', 'first', 'theorized', 'radiation', 'always', 'thought', 'deepmind', 'ode', 'hassabis', 'says', 'hassabis', 'always', 'obsessed', 'unlocks', 'acquire', 'second', 'best', 'chess', 'player', 'world', 'age', 'graduated', 'high', 'school', 'year', 'early', 'adult', 'strikes', 'somewhat', 'figure', 'presence', 'fills', 'room', 'want', 'big', 'questions', 'really', 'big', 'ones', 'normally', 'go', 'physics', 'says', 'thought', 'building', 'ai', 'would', 'fastest', 'route', 'answer', 'questions', 'google', 'parent', 'company', 'one', 'world', 'leading', 'labs', 'last', 'summer', 'announced', 'one', 'alphafold', 'predicted', 'nearly', 'proteins', 'known', 'humanity', 'company', 'making', 'behind', 'freely', 'available', 'long', 'familiar', 'sequences', 'amino', 'acids', 'make', 'proteins', 'building', 'blocks', 'life', 'never', 'cracked', 'fold', 'complex', 'shapes', 'crucial', 'behavior', 'human', 'body', 'alphafold', 'already', 'force', 'hundreds', 'thousands', 'working', 'efforts', 'malaria', 'vaccines', 'fighting', 'tackling', 'plastic', 'pollution', 'company', 'says', 'deepmind', 'applying', 'similar', 'machine', 'learning', 'puzzle', 'nuclear', 'fusion', 'hoping', 'helps', 'yield', 'abundant', 'source', 'cheap', 'zero', 'carbon', 'energy', 'could', 'wean', 'global', 'economy', 'fossil', 'fuels', 'critical', 'juncture', 'climate', 'crisis', 'hassabis', 'says', 'efforts', 'beginning', 'working', 'toward', 'much', 'grander', 'ambition', 'creating', 'general', 'agi', 'building', 'machines', 'think', 'learn', 'set', 'solve', 'humanity', 'toughest', 'problems', 'today', 'ai', 'narrow', 'brittle', 'often', 'agi', 'hassabis', 'believes', 'ep ...
# ...
# https://www.pwc.com/gx/en/issues/workforce/hopes-and-fears-2022.html ['pwc', 'global', 'workforce', 'hopes', 'fears', 'survey', 'pwc', 'skip', 'content', 'skip', 'footer', 'services', 'issues', 'us', 'careers', 'search', 'menu', 'see', 'aerospace', 'defence', 'security', 'capital', 'projects', 'consumer', 'markets', 'energy', 'utilities', 'resources', 'financial', 'services', 'forest', 'paper', 'packaging', 'public', 'services', 'leisure', 'insurance', 'life', 'sciences', 'private', 'equity', 'media', 'logistics', 'menu', 'see', 'menu', 'aerospace', 'defence', 'security', 'space', 'menu', 'menu', 'capital', 'projects', 'menu', 'consumer', 'markets', 'menu', 'energy', 'utilities', 'resources', 'chemicals', 'mining', 'metals', 'oil', 'gas', 'power', 'utilities', 'menu', 'menu', 'financial', 'services', 'asset', 'wealth', 'banking', 'capital', 'markets', 'insurance', 'menu', 'forest', 'paper', 'packaging', 'menu', 'public', 'services', 'defence', 'education', 'security', 'menu', 'menu', 'leisure', 'menu', 'menu', 'insurance', 'menu', 'life', 'sciences', 'menu', 'private', 'equity', 'sovereign', 'funds', 'menu', 'media', 'media', 'menu', 'logistics', 'featured', 'global', 'consumer', 'insights', 'pulse', 'survey', 'june', 'achieving', 'net', 'zero', 'coo', 'pulse', 'survey', 'menu', 'services', 'services', 'see', 'services', 'alliances', 'audit', 'assurance', 'services', 'crisis', 'deals', 'private', 'business', 'family', 'business', 'forensics', 'legal', 'business', 'solutions', 'people', 'strategy', 'climate', 'change', 'tax', 'menu', 'services', 'see', 'services', 'menu', 'services', 'alliances', 'menu', 'services', 'audit', 'assurance', 'services', 'actuarial', 'services', 'capital', 'markets', 'corporate', 'reporting', 'financial', 'audit', 'ifrs', 'internal', 'audit', 'risk', 'assurance', 'menu', 'services', 'cloud', 'digital', 'deals', 'finance', 'forensics', 'front', 'office', 'hr', 'people', 'risk', 'strategy', 'menu', 'services', 'crisis', 'menu', 'services', 'deals', 'capital', 'markets', 'corporate', 'finance', 'deals', 'strategy', 'global', 'fund', 'advisory', 'platform', 'joint', 'ventures', 'alliances', 'legal', 'tax', 'crisis', 'sovereign', 'wealth', 'funds', 'value', 'creation', 'menu', 'services', 'private', 'business', 'menu', 'services', 'family', 'business', 'menu', 'services', 'forensics', 'menu', 'services', 'legal', 'business', 'solutions', 'entity', 'business', 'mergers', 'newlaw', 'menu', 'services', 'people', 'culture', 'change', 'diversity', 'inclusion', 'law', 'tax', 'costs', 'hr', 'design', 'people', 'analytics', 'insights', 'people', 'deals', 'pensions', 'reward', 'benefits', 'workforce', 'strategy', 'menu', 'services', 'strategy', 'menu', 'services', 'climate', 'change', 'esg', 'reporting', 'investing', 'impact', 'legal', 'esg', 'making', 'net', 'zero', 'strategic', 'supply', 'chain', 'goals', 'sdgs', 'tax', 'esg', 'total', 'impact', 'timm', 'menu', 'services', 'tax', 'indirect', 'taxes', 'tax', 'services', 'mergers', 'tax', 'code', 'conduct', 'tax', 'dispute', 'tax', 'policy', 'tax', 'reporting', 'strategy', 'transfer', 'pricing', 'featured', 'ukraine', 'tax', 'legal', 'people', 'digital', 'trust', 'insights', 'survey', 'industry', 'trends', 'report', 'menu', 'issues', 'issues', 'see', 'issues', 'esg', 'social', 'suite', 'insights', 'risk', 'trust', 'value', 'creation', 'workforce', 'menu', 'issues', 'see', 'issues', 'menu', 'issues', 'menu', 'issues', 'esg', 'social', 'energy', 'nature', 'menu', 'issues', 'suite', 'insights', 'global', 'ceo', 'survey', 'strategy', 'business', 'digital', 'issue', 'agenda', 'pwc', 'davos', 'menu', 'issues', 'menu', 'issues', 'risk', 'menu', 'issues', 'menu', 'issues', 'menu', 'issues', 'trust', 'menu', 'issues', 'menu', 'issues', 'value', 'creation', 'menu', 'issues', 'workforce', 'featured', 'agenda', 'th', 'annual', 'global', 'ceo', 'survey', 'strategy', 'business', 'pwc', 'menu', 'us', 'us', 'see', 'us', 'alumni', 'analyst', 'relations', 'client', 'case', 'studie ...
# https://www.technologyreview.com/2023/02/08/1068068/chatgpt-is-everywhere-heres-where-it-came-from/ ['chatgpt', 'came', 'mit', 'review', 'need', 'enable', 'view', 'site', 'skip', 'review', 'came', 'breakout', 'hit', 'overnight', 'built', 'decades', 'research', 'douglas', 'stephanie', 'arnett', 'mittr', 'tech', 'review', 'explains', 'let', 'writers', 'untangle', 'complex', 'messy', 'world', 'help', 'coming', 'next', 'read', 'reached', 'peak', 'chatgpt', 'released', 'end', 'november', 'web', 'app', 'san', 'francisco', 'based', 'firm', 'openai', 'chatbot', 'exploded', 'almost', 'overnight', 'according', 'estimates', 'fastest', 'growing', 'internet', 'service', 'ever', 'reaching', 'million', 'users', 'january', 'two', 'months', 'launch', 'openai', 'billion', 'deal', 'microsoft', 'tech', 'built', 'office', 'software', 'bing', 'search', 'engine', 'stung', 'action', 'newly', 'awakened', 'onetime', 'rival', 'battle', 'search', 'google', 'fast', 'tracking', 'rollout', 'chatbot', 'lamda', 'even', 'family', 'whatsapp', 'filled', 'chatgpt', 'chat', 'openai', 'breakout', 'hit', 'come', 'nowhere', 'chatbot', 'polished', 'iteration', 'date', 'line', 'large', 'language', 'models', 'going', 'back', 'years', 'got', 'recurrent', 'neural', 'networks', 'chatgpt', 'version', 'gpt', 'large', 'language', 'model', 'also', 'developed', 'openai', 'language', 'models', 'type', 'neural', 'network', 'trained', 'lots', 'lots', 'text', 'neural', 'networks', 'software', 'inspired', 'way', 'neurons', 'animal', 'brains', 'signal', 'one', 'another', 'text', 'made', 'sequences', 'letters', 'words', 'varying', 'lengths', 'language', 'models', 'require', 'type', 'neural', 'network', 'make', 'sense', 'kind', 'data', 'recurrent', 'neural', 'networks', 'invented', 'handle', 'sequences', 'words', 'slow', 'train', 'forget', 'previous', 'words', 'sequence', 'computer', 'sepp', 'jürgen', 'fixed', 'inventing', 'lstm', 'long', 'short', 'term', 'memory', 'networks', 'recurrent', 'neural', 'networks', 'special', 'allowed', 'past', 'data', 'input', 'sequence', 'retained', 'longer', 'lstms', 'could', 'handle', 'strings', 'text', 'several', 'hundred', 'words', 'long', 'language', 'skills', 'limited', 'behind', 'today', 'large', 'language', 'models', 'came', 'team', 'google', 'invented', 'kind', 'neural', 'network', 'track', 'word', 'phrase', 'appears', 'sequence', 'meaning', 'words', 'often', 'depends', 'meaning', 'words', 'come', 'tracking', 'handle', 'longer', 'strings', 'text', 'capture', 'meanings', 'words', 'example', 'hot', 'dog', 'means', 'different', 'things', 'sentences', 'hot', 'dogs', 'given', 'plenty', 'water', 'hot', 'dogs', 'eaten', 'mustard', 'gpt', 'gpt', 'openai', 'first', 'two', 'large', 'language', 'models', 'came', 'months', 'apart', 'company', 'wants', 'develop', 'multi', 'skilled', 'general', 'purpose', 'ai', 'believes', 'large', 'language', 'models', 'key', 'step', '
', 'replaced', 'robots', 'first', 'asked', 'estimate', 'employees', 'whose', 'employers', 'replaced', 'jobs', 'robots', 'asked', 'whether', 'employer', 'ever', 'replaced', 'job', 'robot', 'workers', 'say', 'job', 'replaced', 'robot', 'job', 'overstate', 'effect', 'robot', 'takeover', 'three', 'times', 'photo', 'jaren', 'wilkey', 'byu', 'photo', 'workers', 'say', 'job', 'replaced', 'robot', 'job', 'overstate', 'effect', 'robot', 'takeover', 'three', 'times', 'photo', 'jaren', 'wilkey', 'byu', 'photo', 'replaced', 'robot', 'estimated', 'jobs', 'taken', 'robots', 'similarly', 'job', 'still', 'estimated', 'jobs', 'robots', 'overall', 'robots', 'taking', 'greatly', 'said', 'dahlin', 'lost', 'jobs', 'double', 'lost', 'jobs', 'three', 'times', 'attention', 'grabbing', 'headlines', 'dire', 'future', 'likely', 'overblown', 'threat', 'robots', 'taking', 'jobs', 'said', 'dahlin', 'noted', 'humans', 'fear', 'replaced', 'automated', 'work', 'processes', 'dates', 'early', 'expect', 'novel', 'adopted', 'without', 'relevant', 'cultural', 'economic', 'support', 'sale', 'use', 'said', 'used', 'something', 'mean', 'dahlin', 'says', 'findings', 'previous', 'studies', 'suggest', 'robots', 'workers', 'rather', 'employees', 'robots', 'ways', 'generate', 'value', 'human', 'labor', 'everyday', 'example', 'self', 'propelled', 'machine', 'roaming', 'isles', 'cleaning', 'floors', 'local', 'grocery', 'store', 'says', 'dahlin', 'robot', 'cleans', 'floors', 'employees', 'clean', 'shelves', 'difficult', 'to', 'reach', 'places', 'dahlin', 'says', 'aviation', 'industry', 'another', 'good', 'example', 'robots', 'humans', 'working', 'together', 'airplane', 'used', 'robots', 'paint', 'airplane', 'wings', 'robot', 'one', 'coat', 'paint', 'minutes', 'something', 'would', 'take', 'human', 'painter', 'hours', 'humans', 'load', 'unload', 'paint', 'robot', 'painting', 'media', 'contact', 'tyler', 'stahle', 'tags', 'family', 'home', 'social', 'sciences', 'sociology', 'read', 'bbc', 'ai', 'magazine', 'related', 'articles', 'data', 'content', 'type', 'article', 'intellect', 'awards', 'season', 'byu', 'students', 'honored', 'first', 'place', 'finishes', 'tyler', 'stahle', 'may', 'rise', 'shout', 'across', 'various', 'byu', 'students', 'world', 'class', 'min', 'read', 'false', 'true', 'false', 'data', 'content', 'type', 'article', 'character', 'adh ...
# https://www.bbc.com/worklife/work-in-progress ['work', 'progress', 'bbc', 'worklife', 'linksskip', 'helpbbc', 'menu', 'search', 'bbc', 'search', 'bbc', 'menu', 'work', 'worklife', 'workhow', 'livehow', 'website', 'produced', 'bbc', 'global', 'news', 'ltd', 'company', 'part', 'bbc', 'studios', 'owned', 'bbc', 'bbc', 'money', 'licence', 'fee', 'used', 'create', 'website', 'money', 'make', 're', 'invested', 'help', 'fund', 'bbc', 'first', 'remote', 'hybrid', 'next', 'clear', 'answer', 'modern', 'workplace', 'know', 'changed', 'still', 'work', 'progress', 'work', 'anxiety', 'replaced', 'aiby', 'josie', 'coxwork', 'end', 'desks', 'alex', 'progress', 'day', 'week', 'too', 'short', 'staffed', 'work', 'by', 'alex', 'progressa', 'remote', 'work', 'change', 'heart', 'megan', 'tatumwork', 'burnout', 'may', 'never', 'endby', 'alex', 'problem', 'pushing', 'workers', 'farby', 'alex', 'hitting', 'gen', 'workersby', 'megan', 'bosses', 'rolling', 'back', 'remote', 'workby', 'alex', 'ripple', 'effects', 'layoffsby', 'josie', 'coxwork', 'done', 'cv', 'gap', 'taboo', 'alex', 'worker', 'kate', 'morgan', 'delaney', 'nolanwork', 'gets', 'four', 'day', 'workweek', 'joanna', 'yorkhow', 'workthe', 'companies', 'burn', 'young', 'gradsby', 'alex', 'workthe', 'axed', 'workers', 'posting', 'epic', 'alex', 'workthe', 'workers', 'laid', 'first', 'timeby', 'megan', 'tatumhow', 'workthe', 'workers', 'lured', 'oversold', 'jobsby', 'joanna', 'yorkload', 'articles', 'explore', 'useabout', 'bbcmake', 'editorial', 'emails', 'bbc', 'bbc', 'content', 'external', 'sites', 'read', 'approach', 'external', 'linking']

# %%
# dataFrame['clean'] = dataFrame.apply(lambda row: final_clean(row['links']), axis =1)
dataFrame['clean'] = dataFrame.apply(lambda column: final_clean(second_clean(clean(tokenized(r['links'])))), axis =1)
# dataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # dataFrame['clean'] = dataFrame.apply(lambda row: final_clean(row['links']), axis =1)
# ----> 2 dataFrame['clean'] = dataFrame.apply(lambda column: final_clean(second_clean(clean(tokenized(r['links'])))), axis =1)
#       3 # dataFrame
#
# File c:\users\diana\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File c:\users\diana\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File c:\users\diana\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File c:\users\diana\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[31], line 2, in <lambda>(column)
#       1 # dataFrame['clean'] = dataFrame.apply(lambda row: final_clean(row['links']), axis =1)
# ----> 2 dataFrame['clean'] = dataFrame.apply(lambda column: final_clean(second_clean(clean(tokenized(r['links'])))), axis =1)
#       3 # dataFrame
#
# NameError: name 'r' is not defined

# %%
#dataFrame.to_csv('Cleaned_data.csv')
